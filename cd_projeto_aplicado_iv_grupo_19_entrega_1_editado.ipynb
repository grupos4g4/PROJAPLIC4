# %% [markdown]
# <a href="https://colab.research.google.com/github/grupos4g4/PROJAPLIC4/blob/main/cd_projeto_aplicado_iv_grupo_19_entrega_1_editado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   <img src="https://raw.githubusercontent.com/scalabrinig/cdProjetoAplicadoIV/d093146488f56dfcf0ef286bcee8efe0e71b9c76/figuras/mackenzie_logo.jpg" width="25%" align="right"/>
#
# # **PROJETO APLICADO IV - Ciência de Dados EaD - 2025/02**
#
#
# # **Entrega 1**
#
# ---

# %% [markdown]
# # **Evasão na Educação a Distância no Ensino Superior Brasileiro (2013–2023): Mensuração por Séries Temporais e Cenários de Curto Prazo**:
#
# ---

# %%
#@title **Identificação do Grupo e Opção do Projeto**

#@markdown Integrantes do Grupo, nome completo em ordem alfabética (*informe: \<nome\>, \<matrícula\>*)
Aluno1 = 'Anderson Aparecido da Silva Alves, 10347602' #@param {type:"string"}
Aluno2 = 'Andreia Domingos dos Santos, 10288503' #@param {type:"string"}
Aluno3 = 'Gerson Soares Rodrigues, 10423804' #@param {type:"string"}
Aluno4 = 'Samuel Bonfim da Silva, 10423569' #@param {type:"string"}

# %% [markdown]
# # **Introdução**
#
# Este projeto situa-se na interseção entre a Ciência de Dados — com ênfase em modelagem de séries temporais, estatística aplicada e aprendizado de máquina — e os estudos de gestão e políticas da Educação Superior. Tomando como base o Censo da Educação Superior (Inep) e referências setoriais, estruturamos uma investigação sobre a evasão de estudantes na modalidade a distância (EAD) após o início do curso.
#
# Diante desta problemática, buscaremos investigar por que a evasão em cursos EAD tem se intensificado em diferentes contextos institucionais e regionais, mapeando fatores associados (perfil discente, organização acadêmica, modalidade/turno, área de formação, processo seletivo, desenho pedagógico e condições de oferta) e identificando pontos de mudança ao longo do tempo. O estudo busca produzir evidências para apoiar planejamento acadêmico, políticas de permanência e tomada de decisão em instituições e órgãos reguladores.
#
# Ao longo do texto, utilizamos IES para nos referirmos às Instituições de Educação Superior (universidades, centros universitários, faculdades, Institutos Federais/Cefets), públicas ou privadas.
#
# Aderência às ODS. A proposta se alinha às ODS 8, 9 e 11 de modo a: contribuir para trabalho decente e crescimento econômico ao fortalecer a formação de capital humano; orientar inovação e infraestrutura (inclusive digital) aplicadas à permanência estudantil; e subsidiar o planejamento territorial e a redução de desigualdades regionais no acesso e na conclusão.

# %% [markdown]
# # **Motivações e justificativa**
#
#
# *  *Problema público e institucional.* A evasão pós-início implica perdas para estudantes, IES e sociedade, reduzindo a conversão de ingresso em conclusão e dificultando metas de qualificação e empregabilidade.
# *   *Gestão baseada em evidências.* Compreender causas — e não apenas medir taxas — é essencial para desenhar políticas de permanência, dimensionar turmas, organizar processos seletivos e planejar infraestrutura (presencial e digital).
# *  *Qualidade e permanência.* Evidências setoriais apontam que a permanência decorre de uma combinação de fatores: perfil do aluno (idade, trabalho, tempo disponível), desenho pedagógico (avaliações, trilhas, apoio), suporte acadêmico/tecnológico e modelo de gestão do curso.
# *  *ODS e aplicabilidade.*
#     - ODS 8 – fortalecer capital humano com maior conclusão;
#     - ODS 9 – orientar inovação e infraestrutura educacional voltadas à retenção;
#     - ODS 11 – insumos para planejamento territorial e redução de desigualdades regionais.
# *   *Benefícios esperados.* Entregar diagnóstico explicável e cenários de curto prazo que apoiem ajustes práticos (janelas de intervenção, trilhas de apoio, calendários, reingresso), com rápida implementação por IES e gestores públicos.

# %% [markdown]
# # **Objetivo**
#
# # **Objetivo geral:**
# Investigar as causas e a dinâmica da evasão na EAD após o início do curso, construindo medidas consistentes, modelos de séries temporais e insumos diagnósticos que orientem estratégias de permanência e planejamento setorial, em consonância com as ODS 8, 9 e 11.
#
# ***Perguntas de pesquisa***
# *   Como evolui a evasão ao longo do tempo na EAD e quais pontos de mudança (quebras) podem ser identificados?
# *   Quais fatores institucionais, pedagógicos e de oferta se associam à evasão após o início do curso?
# *   Há diferenças relevantes por categoria administrativa, organização acadêmica, turno, área de formação e região?
# *   Que eventos e mudanças regulatórias se relacionam a variações de evasão ao longo da série?
# *   Que indicadores preditivos de risco (em nível agregado) podem apoiar decisões de gestão e políticas de permanência?
#
# ***Metas da etapa***
# *   Definir e calcular um indicador anual de evasão compatível com as séries do Inep (ex.: evasão média por valor agregado).
# *   Decompor as séries (tendência/sazonalidade) e detectar quebras estruturais, relacionando-as a hipóteses causais.
# *   Comparar padrões entre EAD e presencial e entre segmentos institucionais, priorizando explicabilidade.
# *   Avaliar modelos de previsão de curto prazo para monitoramento contínuo e detecção precoce de risco.
# *   Produzir recomendações operacionais alinhadas às ODS 8, 9 e 11.

# %% [markdown]
# # **Descrição da base de dados**
#
# *Fontes primárias (Inep).*
#
# *   Censo da Educação Superior 2023 — Notas Estatísticas: séries anuais 2013–2023 e indicadores agregados por tema (rede, vagas/ingressantes, matrículas, concluintes, docentes), calculados a partir dos microdados.
# *   Microdados do Censo 2023: nível granular (IES–curso–discente–docente) para reproduzir agregações, derivar o indicador de evasão e validar recortes e sensibilidades metodológicas.
#
# *Fonte setorial complementar (ABED).*
# *   Censo EAD.BR 2023/2024: referência qualitativa sobre práticas de gestão, docência e tecnologia em cursos EAD (útil para interpretar fatores de permanência/evasão e fortalecer a discussão de hipóteses).
#
# *Informações e organização.*
# Trabalharemos com ano, modalidade (EAD/presencial), ingressantes, matriculados e concluintes; a evasão será derivada por método compatível com séries agregadas (nesta entrega, sem exposição de valores numéricos). Os recortes incluirão categoria administrativa, organização acadêmica, turno, área de formação e região. Quando necessário, utilizaremos proxies e complementaremos a interpretação com evidências do Censo EAD.BR.
#
# *Cobertura e coleta.*
# Periodicidade anual; análise de 2013 a 2023 (ano-base 2023). Nesta entrega, detalhamos o plano de medição e investigação; nas próximas, apresentaremos estimativas, validações e previsões.

# %% [markdown]
# # **Referências**
#
# 1.   BRASIL. Instituto Nacional de Estudos e Pesquisas Educacionais Anísio
# Teixeira
# (Inep). Censo da Educação Superior 2023: Notas Estatísticas. Brasília, DF: Inep, 2024.
# 2.  BRASIL. Inep. Apresentação – Censo da Educação Superior 2021. Brasília, DF: Inep, 2022. (Arquivo de apresentação).
# 3. ABED – Associação Brasileira de Educação a Distância. Censo EAD.BR 2023/2024. São Paulo: ABED, 2024.
# 4. CHANAN, P. Comentários aos números do Censo da Educação Superior Brasileira – 2023. [S.l.: s.n.], [s.d.]. (Apresentação).

# %%
#@title **Avaliação**
Introducao = 10 #@param {type:"slider", min:0, max:10, step:1}

Fonte_dos_dados = 10 #@param {type:"slider", min:0, max:10, step:1}

Solucao_proposta = 10 #@param {type:"slider", min:0, max:10, step:1}

Referencias = 10 #@param {type:"slider", min:0, max:10, step:1}

# %%
#@title **Nota Final**
nota = 0.30*Introducao + 0.30*Fonte_dos_dados + 0.30*Solucao_proposta + 0.10*Referencias

print(f'Nota da entrega {nota :.1f}')

import numpy as np
import pandas as pd

alunos = pd.DataFrame()

lista_nome = []

for i in range(1,6):
  exec("if Aluno" + str(i) + " !='None':  lista = Aluno" + str(i) + ".split(','); lista_nome.append(lista[0]);")

alunos['nome'] = lista_nome
alunos['nota'] = np.round(nota,1)
print()
display(alunos)
# Out:
# Nota da entrega 8.5
#       nome  nota
# 0  Aluno 1   8.5
# 1  Aluno 2   8.5
# 2  Aluno 3   8.5
